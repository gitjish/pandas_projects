# %%
import numpy as np  
import pandas as pd

# %%
df = pd.read_csv("woocommerce-product-export.csv",encoding='UTF8')
print('Data downloaded and read into a dataframe!')

df
# Out:
# Data downloaded and read into a dataframe!
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
# 2 Show a concise summary of the columns using info() method.

df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Columns: 9 entries, month_number to total_profit
# dtypes: int64(9)
# memory usage: 992.0 bytes

# %%
#3 Show a summary of statistics pertaining to the columns. 
df.describe()
# Out:
#        month_number    facecream     facewash   toothpaste   bathingsoap  \
# count     12.000000    12.000000    12.000000    12.000000     12.000000
# mean       6.500000  2873.333333  1542.916667  5825.833333   9500.833333
# std        3.605551   584.595172   316.733745  1242.032486   2348.095779
# min        1.000000  1990.000000  1120.000000  4550.000000   6100.000000
# 25%        3.750000  2460.000000  1305.000000  4862.500000   8015.000000
# 50%        6.500000  2830.000000  1527.500000  5530.000000   9090.000000
# 75%        9.250000  3435.000000  1765.000000  6400.000000  10045.000000
# max       12.000000  3700.000000  2100.000000  8300.000000  14400.000000
#
#            shampoo  moisturizer  total_units   total_profit
# count    12.000000    12.000000     12.00000      12.000000
# mean   2117.500000  1542.916667  26027.50000  260275.000000
# std     617.724931   316.733745   7014.36594   70143.659404
# min    1200.000000  1120.000000  18330.00000  183300.000000
# 25%    1795.000000  1305.000000  21065.00000  210650.000000
# 50%    1995.000000  1527.500000  22935.00000  229350.000000
# 75%    2325.000000  1765.000000  29667.50000  296675.000000
# max    3550.000000  2100.000000  41280.00000  412800.000000

# %%
#4 Print the first five rows by default.
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
#5 Print the last five rows by default.
df.tail()
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
#6 Print  the "total_profit," and “month_number” columns only.
df_mtotal=df[["month_number","total_profit"]]
df_mtotal
# Out:
#     month_number  total_profit
# 0              1        211000
# 1              2        183300
# 2              3        224700
# 3              4        222700
# 4              5        209600
# 5              6        201400
# 6              7        295500
# 7              8        361400
# 8              9        234000
# 9             10        266700
# 10            11        412800
# 11            12        300200

# %%
#importing Visualization packages
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot')  # optional: for ggplot-like style

# %%
#7 Read the total profit of all months and show it using the Bar plot. 
'''The generated Bar plot must include the following properties: 
X label name = Month number.
Y label name = Total profit.
Title = Company profit per month.'''
df_mtotal.set_index('month_number', inplace=True)
df_mtotal.plot(kind='bar', figsize=(10, 6))

plt.xlabel('Month number') # add to x-label to the plot
plt.ylabel('Total profit') # add y-label to the plot
plt.title('Company profit per month') # add title to the plot

plt.show()

# %%
#8 Read the total profit of all of the months, and show the line plot with the following style properties:
'''The generated line plot must include the following Style properties: 
The line style should be dotted and the line color should be red.
Show the legend at the lower-right location.
X label name = Month number
Y label name = Total profit.
Title = Company profit per month.
Add a circle marker; the line marker color = red. 
The line width should be 3.'''
df_mtotal.plot(lw=3,linestyle='dotted',marker='o',color='red',xlim=0,ylim=100000,figsize=(10,6))
plt.legend( loc ="lower right")
  
plt.xlabel('Month number') # add to x-label to the plot
plt.ylabel('Total profit') # add y-label to the plot
plt.title('Company profit per month') # add title to the plot

#,Marker=o,MarkerSize =10,MarkerEdgeColor='red'

#plt.text(5, 6000, '2010 Earthquake')
plt.show()

# %%
df_perunit=df[['month_number','facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']]
df_perunit.set_index('month_number',inplace= True)
df_perunit
# Out:
#               facecream  facewash  toothpaste  bathingsoap  shampoo  \
# month_number
# 1                  2500      1500        5200         9200     1200
# 2                  2630      1200        5100         6100     2100
# 3                  2140      1340        4550         9550     3550
# 4                  3400      1130        5870         8870     1870
# 5                  3600      1740        4560         7760     1560
# 6                  2760      1555        4890         7490     1890
# 7                  2980      1120        4780         8980     1780
# 8                  3700      1400        5860         9960     2860
# 9                  3540      1780        6100         8100     2100
# 10                 1990      1890        8300        10300     2300
# 11                 2340      2100        7300        13300     2400
# 12                 2900      1760        7400        14400     1800
#
#               moisturizer
# month_number
# 1                    1500
# 2                    1200
# 3                    1340
# 4                    1130
# 5                    1740
# 6                    1555
# 7                    1120
# 8                    1400
# 9                    1780
# 10                   1890
# 11                   2100
# 12                   1760

# %%
#9 Print all of the product sales data and show it using a multi-line plot.
#Display the number of units sold per month for each product using multi-line plots. (i.e., show a separate Plotline for each product).
#df_mtotal.set_index('month_number', inplace=True)

df_perunit.plot(kind='line',lw=2,marker='o',figsize=(12,8))
plt.xlabel('Month number') # add to x-label to the plot
plt.ylabel('Sales Unit In Number') # add y-label to the plot
plt.title('Company profit per month') # add title to the plot

plt.show()

# %%
#10 Read “bathingsoap” sales data for each month and show it using a scatter plot.
#Add a grid to the plot. The grid line style should be “–“.
#The scatter plot should look like the screenshot below:

df_soap=df[['month_number','bathingsoap']]
df_soap
# Out:
#     month_number  bathingsoap
# 0              1         9200
# 1              2         6100
# 2              3         9550
# 3              4         8870
# 4              5         7760
# 5              6         7490
# 6              7         8980
# 7              8         9960
# 8              9         8100
# 9             10        10300
# 10            11        13300
# 11            12        14400

# %%
#df_soap.plot(kind='scatter', x='month_number',  y='bathingsoap',linestyle='-', figsize=(10, 6), color='darkblue')
plt.rc('grid', linestyle='dotted',alpha=0.3,color='black')
df_soap.plot.scatter(x='month_number', y='bathingsoap', figsize=(8, 6), size=40,color='darkblue')
plt.grid(True)

plt.xlabel('Month number') # add to x-label to the plot
plt.ylabel('Number of Units Sold') # add y-label to the plot
plt.title('Bathing Soap Sales Data') # add title to the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Section Two
# -------------
# Below are the Tasks:
#
# Given Dataset:
# date=["25/12","26/12","27/12"]
# temp=[8.5,10.5,6.8]

# %%
''' qn 1 A line chart of date versus temperature must include the following properties: 
X label name = Date
Y label name = temperature
Title = Date-wise Temperature'''

date=["25/12","26/12","27/12"]
temp=[8.5,10.5,6.8]
x=date
y=temp
plt.plot(x, y, linestyle='-')

plt.xlabel('Date') # add to x-label to the plot
plt.ylabel('Temperature') # add y-label to the plot
plt.title('Date-wise Temperature') # add title to the plot
plt.show()

# %%
'''Given Dataset:
height=[121.9,124.5,129.5,134.6,139.7,147.3,152.4,157.5,162.6]
weight=[19.7,21.3,23.5,25.9,28.5,32.1,35.7,39.6,43.2]

Show the average weight against the average height (use a line chart or any other chart):
The generated line plot must include the following Style properties:
The line style should be dash-dot and the line color should be green.
Show the legend at the lower-right location.
X label name =Weight in kg.
Y label name = Height in cm.
Title = Average weight with respect to average height.
Add a circle marker: marker size =10; circle marker color = green.'''
height=[121.9,124.5,129.5,134.6,139.7,147.3,152.4,157.5,162.6]
weight=[19.7,21.3,23.5,25.9,28.5,32.1,35.7,39.6,43.2]
x=weight
y=height
plt.plot(x, y, linestyle='-.',color='green',marker='o',markersize=10)

plt.xlabel('Weight in kg') # add to x-label to the plot
plt.ylabel('Height in cm') # add y-label to the plot
plt.title('Average weight with respect to average height') # add title to the plot
plt.show()
